# %% [markdown]
# Objective: Create a ML model to predict whether the humidity will be high at 3pm or not.

# %%
import pandas as pd
df=pd.read_csv(r'daily_weather.csv')
df
# Out:
#       air_pressure_9am  air_temp_9am  avg_wind_direction_9am  \
# 0           918.060000     74.822000              271.100000
# 1           917.347688     71.403843              101.935179
# 2           923.040000     60.638000               51.000000
# 3           920.502751     70.138895              198.832133
# 4           921.160000     44.294000              277.800000
# ...                ...           ...                     ...
# 1090        918.900000     63.104000              192.900000
# 1091        918.710000     49.568000              241.600000
# 1092        916.600000     71.096000              189.300000
# 1093        912.600000     58.406000              172.700000
# 1094        921.530000     77.702000               97.100000
#
#       avg_wind_speed_9am  max_wind_direction_9am  max_wind_speed_9am  \
# 0               2.080354              295.400000            2.863283
# 1               2.443009              140.471549            3.533324
# ...

# %%
df.shape
# Out:
# (1095, 10)

# %%
df.isnull().sum()
# Out:
# air_pressure_9am          3
# air_temp_9am              5
# avg_wind_direction_9am    4
# avg_wind_speed_9am        3
# max_wind_direction_9am    3
# max_wind_speed_9am        4
# rain_accumulation_9am     6
# rain_duration_9am         3
# relative_humidity_9am     0
# high_humidity_3pm         0
# dtype: int64

# %%
df.columns
# Out:
# Index(['air_pressure_9am', 'air_temp_9am', 'avg_wind_direction_9am',
#        'avg_wind_speed_9am', 'max_wind_direction_9am', 'max_wind_speed_9am',
#        'rain_accumulation_9am', 'rain_duration_9am', 'relative_humidity_9am',
#        'high_humidity_3pm'],
#       dtype='object')

# %%
df.dropna(axis=0, inplace=True)

# %%
df.isnull().sum()
# Out:
# air_pressure_9am          0
# air_temp_9am              0
# avg_wind_direction_9am    0
# avg_wind_speed_9am        0
# max_wind_direction_9am    0
# max_wind_speed_9am        0
# rain_accumulation_9am     0
# rain_duration_9am         0
# relative_humidity_9am     0
# high_humidity_3pm         0
# dtype: int64

# %% [markdown]
# Split the dataset into input features and target columns

# %%
x=df.drop('high_humidity_3pm',axis=1)
y=df['high_humidity_3pm']
x.head()
# Out:
#    air_pressure_9am  air_temp_9am  avg_wind_direction_9am  avg_wind_speed_9am  \
# 0        918.060000     74.822000              271.100000            2.080354
# 1        917.347688     71.403843              101.935179            2.443009
# 2        923.040000     60.638000               51.000000           17.067852
# 3        920.502751     70.138895              198.832133            4.337363
# 4        921.160000     44.294000              277.800000            1.856660
#
#    max_wind_direction_9am  max_wind_speed_9am  rain_accumulation_9am  \
# 0              295.400000            2.863283                    0.0
# 1              140.471549            3.533324                    0.0
# 2               63.700000           22.100967                    0.0
# 3              211.203341            5.190045                    0.0
# 4              136.500000            2.863283                    8.9
#
#    rain_duration_9am  relative_humidity_9am
# ...

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    0
# 3    0
# 4    1
# Name: high_humidity_3pm, dtype: int64

# %% [markdown]
# Scaling the input feature data

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
x_scaled=scaler.fit_transform(x)
x_scaled
# Out:
# array([[0.47210502, 0.61251086, 0.77950595, ..., 0.        , 0.        ,
#         0.41985439],
#        [0.43871018, 0.55751589, 0.26360225, ..., 0.        , 0.        ,
#         0.21077889],
#        [0.705579  , 0.3843035 , 0.10826471, ..., 0.        , 0.00112969,
#         0.03247429],
#        ...,
#        [0.40365682, 0.55256299, 0.53003965, ..., 0.        , 0.        ,
#         0.45648908],
#        [0.21612752, 0.3483927 , 0.47941446, ..., 0.        , 0.        ,
#         0.67895528],
#        [0.63478669, 0.65884738, 0.24885636, ..., 0.        , 0.        ,
#         0.09788513]])

# %%
x_scaled=pd.DataFrame(x_scaled, columns=x.columns)
x_scaled.head()
# Out:
#    air_pressure_9am  air_temp_9am  avg_wind_direction_9am  avg_wind_speed_9am  \
# 0          0.472105      0.612511                0.779506            0.060665
# 1          0.438710      0.557516                0.263602            0.076528
# 2          0.705579      0.384304                0.108265            0.716243
# 3          0.586627      0.537164                0.559110            0.159391
# 4          0.617440      0.121344                0.799939            0.050881
#
#    max_wind_direction_9am  max_wind_speed_9am  rain_accumulation_9am  \
# 0                0.940699            0.058548               0.000000
# 1                0.393828            0.081931               0.000000
# 2                0.122838            0.729899               0.000000
# 3                0.643499            0.139747               0.000000
# 4                0.379809            0.058548               0.370525
#
#    rain_duration_9am  relative_humidity_9am
# ...

# %% [markdown]
# Divide into train dataset and test dataset

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.2,random_state=42)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((876, 9), (219, 9), (876,), (219,))

# %%
x_test.head()
# Out:
#      air_pressure_9am  air_temp_9am  avg_wind_direction_9am  \
# 533          0.369433      0.640313                0.637389
# 139          0.653694      0.448342                0.176009
# 88           0.371516      0.525097                0.095261
# 841          0.486639      0.582103                0.515401
# 985          0.548992      0.672169                0.523025
#
#      avg_wind_speed_9am  max_wind_direction_9am  max_wind_speed_9am  \
# 533            0.064579                0.659725            0.060109
# 139            0.136567                0.222849            0.123814
# 88             0.449817                0.126173            0.457580
# 841            0.057730                0.557007            0.055425
# 985            0.185910                0.582068            0.158470
#
#      rain_accumulation_9am  rain_duration_9am  relative_humidity_9am
# 533                    0.0           0.000000               0.377095
# ...

# %%
y_test.head()
# Out:
# 533    1
# 139    0
# 88     0
# 841    0
# 985    0
# Name: high_humidity_3pm, dtype: int64

# %% [markdown]
# Apply ML algo into training data

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier(max_leaf_nodes=10, criterion='entropy')
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_leaf_nodes=10)

# %% [markdown]
# Model Prediction

# %%
y_pred=model.predict(x_test)
y_pred[:5]
# Out:
# array([1, 0, 0, 0, 0], dtype=int64)

# %%
y_test[:5]
# Out:
# 533    1
# 139    0
# 88     0
# 841    0
# 985    0
# Name: high_humidity_3pm, dtype: int64

# %% [markdown]
# Model Evaluation

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
cm=confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[104,  16],
#        [  7,  92]], dtype=int64)

# %%
sns.heatmap(cm,annot=True, fmt='d')
# Out:
# <Axes: >

# %%
accuracy_score(y_test, y_pred)*100
# Out:
# 89.49771689497716

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.87      0.90       120
#            1       0.85      0.93      0.89        99
#
#     accuracy                           0.89       219
#    macro avg       0.89      0.90      0.89       219
# weighted avg       0.90      0.89      0.90       219

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

plt.figure(figsize=(20,10))
plot_tree(model,
          feature_names=x_train.columns,
          class_names=['0', '1'],
          filled=True,
          rounded=True,
          fontsize=12)
plt.show()

# %% [markdown]
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=model.predict(x_test)
y_pred[:5]
# Out:
# array([1, 0, 0, 0, 0], dtype=int64)

# %%
y_test[:5]
# Out:
# 533    1
# 139    0
# 88     0
# 841    0
# 985    0
# Name: high_humidity_3pm, dtype: int64

# %%
cm=confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[105,  15],
#        [ 14,  85]], dtype=int64)

# %%
accuracy_score(y_test, y_pred)*100
# Out:
# 86.7579908675799

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.88      0.88       120
#            1       0.85      0.86      0.85        99
#
#     accuracy                           0.87       219
#    macro avg       0.87      0.87      0.87       219
# weighted avg       0.87      0.87      0.87       219

# %% [markdown]
# KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
model=KNeighborsClassifier(n_neighbors=5)
model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred=model.predict(x_test)
y_pred[:5]
# Out:
# array([1, 0, 0, 0, 0], dtype=int64)

# %%
y_test[:5]
# Out:
# 533    1
# 139    0
# 88     0
# 841    0
# 985    0
# Name: high_humidity_3pm, dtype: int64

# %%
cm=confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[107,  13],
#        [  8,  91]], dtype=int64)

# %%
accuracy_score(y_test, y_pred)*100
# Out:
# 90.41095890410958

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.89      0.91       120
#            1       0.88      0.92      0.90        99
#
#     accuracy                           0.90       219
#    macro avg       0.90      0.91      0.90       219
# weighted avg       0.91      0.90      0.90       219

# %% [markdown]
# Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
model=GaussianNB()
model.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
model.score(x_test,y_test)
# Out:
# 0.821917808219178

# %%
Project Summary: 
Using Decision Tree Algorithm we have got 89.49% accuracy, logistic regression we have got 86.75% accuracy, knn we got 90.41% and naive bayes algorithm gives least accuracy score that is 82.19%.
