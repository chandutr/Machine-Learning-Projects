# %%
import pandas as pd
df=pd.read_csv(r'traindata.csv')
df
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
df.shape
# Out:
# (569, 31)

# %%
df.isnull().sum()
# Out:
# mean radius                0
# mean texture               0
# mean perimeter             0
# mean area                  0
# mean smoothness            0
# mean compactness           0
# mean concavity             0
# mean concave points        0
# mean symmetry              0
# mean fractal dimension     0
# radius error               0
# texture error              0
# perimeter error            0
# area error                 0
# smoothness error           0
# compactness error          0
# concavity error            0
# concave points error       0
# symmetry error             0
# fractal dimension error    0
# worst radius               0
# worst texture              0
# worst perimeter            0
# worst area                 0
# worst smoothness           0
# worst compactness          0
# worst concavity            0
# worst concave points       0
# worst symmetry             0
# worst fractal dimension    0
# target                     0
# dtype: int64

# %%
df.describe()
# Out:
#        mean radius  mean texture  mean perimeter    mean area  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        mean smoothness  mean compactness  mean concavity  mean concave points  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %%
col=df.columns
for col in col:
    print(df[col].value_counts())
# Out:
# mean radius
# 12.34    4
# 11.71    3
# 12.46    3
# 13.05    3
# 10.26    3
#         ..
# 12.23    1
# 14.45    1
# 19.18    1
# 18.08    1
# 7.76     1
# Name: count, Length: 456, dtype: int64
# mean texture
# 20.52    3
# 16.85    3
# 16.84    3
# 19.83    3
# 14.93    3
#         ..
# 18.58    1
# 15.11    1
# 22.41    1
# 14.92    1
# 24.54    1
# Name: count, Length: 479, dtype: int64
# mean perimeter
# 82.61     3
# 87.76     3
# 134.70    3
# 93.97     2
# 82.69     2
#          ..
# 127.50    1
# 90.63     1
# 82.53     1
# 100.40    1
# 47.92     1
# Name: count, Length: 522, dtype: int64
# mean area
# 512.2     3
# 1075.0    2
# 582.7     2
# 399.8     2
# 641.2     2
#          ..
# 507.4     1
# 609.9     1
# 463.7     1
# 428.9     1
# 181.0     1
# Name: count, Length: 539, dtype: int64
# mean smoothness
# 0.10070    5
# 0.11500    4
# 0.10540    4
# 0.10750    4
# 0.10630    3
#           ..
# 0.08876    1
# 0.09965    1
# 0.13230    1
# 0.08968    1
# 0.05263    1
# ...

# %% [markdown]
# Split the dataset into input features and target columns

# %%
x=df.drop('target', axis=1)
y=df['target']
x.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# ...

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: target, dtype: int64

# %% [markdown]
# Divide into train dataset and test dataset

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=0)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((426, 30), (143, 30), (426,), (143,))

# %%
x_test.head()
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 512        13.40         20.52           88.64      556.7          0.11060
# 457        13.21         25.25           84.10      537.9          0.08791
# 439        14.02         15.66           89.59      606.5          0.07966
# 298        14.26         18.17           91.22      633.1          0.06576
# 37         13.03         18.42           82.61      523.8          0.08983
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 512           0.14690         0.14450              0.08172         0.2116
# 457           0.05205         0.02772              0.02068         0.1619
# 439           0.05581         0.02087              0.02652         0.1589
# 298           0.05220         0.02475              0.01374         0.1635
# 37            0.03766         0.02562              0.02923         0.1467
#
#      mean fractal dimension  ...  worst radius  worst texture  \
# ...

# %%
y_test.head()
# Out:
# 512    0
# 457    1
# 439    1
# 298    1
# 37     1
# Name: target, dtype: int64

# %% [markdown]
# Apply ML Algo into training data

# %%
from sklearn.ensemble import RandomForestClassifier
classifier=RandomForestClassifier()
classifier.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=classifier.predict(x_test)
y_pred[:5]
# Out:
# array([0, 1, 1, 1, 1], dtype=int64)

# %%
y_test[:5]
# Out:
# 512    0
# 457    1
# 439    1
# 298    1
# 37     1
# Name: target, dtype: int64

# %% [markdown]
# Model Evalation

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
accuracy_score(y_test, y_pred)*100
# Out:
# 97.2027972027972

# %%
print(confusion_matrix(y_test, y_pred))
# Out:
# [[52  1]
#  [ 3 87]]

# %%
import seaborn as sns 
sns.heatmap(confusion_matrix(y_test,y_pred), annot=True, fmt='d')
# Out:
# <Axes: >

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.96        53
#            1       0.99      0.97      0.98        90
#
#     accuracy                           0.97       143
#    macro avg       0.97      0.97      0.97       143
# weighted avg       0.97      0.97      0.97       143

# %% [markdown]
# Visualize the feature scores of input features

# %%
classifier.feature_importances_
# Out:
# array([0.03300302, 0.01240464, 0.03670803, 0.04369591, 0.00409819,
#        0.01567173, 0.04990436, 0.14515704, 0.00553028, 0.00227955,
#        0.02281717, 0.00499173, 0.00893699, 0.03583976, 0.00552803,
#        0.00557354, 0.00883607, 0.00554329, 0.00453802, 0.0037646 ,
#        0.116778  , 0.01763301, 0.12309562, 0.07561052, 0.00959931,
#        0.01815846, 0.04903318, 0.11560885, 0.01016677, 0.00949435])

# %%
feature_scores=pd.Series(classifier.feature_importances_, index=x.columns).sort_values(ascending=False)
feature_scores
# Out:
# mean concave points        0.145157
# worst perimeter            0.123096
# worst radius               0.116778
# worst concave points       0.115609
# worst area                 0.075611
# mean concavity             0.049904
# worst concavity            0.049033
# mean area                  0.043696
# mean perimeter             0.036708
# area error                 0.035840
# mean radius                0.033003
# radius error               0.022817
# worst compactness          0.018158
# worst texture              0.017633
# mean compactness           0.015672
# mean texture               0.012405
# worst symmetry             0.010167
# worst smoothness           0.009599
# worst fractal dimension    0.009494
# perimeter error            0.008937
# concavity error            0.008836
# compactness error          0.005574
# concave points error       0.005543
# mean symmetry              0.005530
# smoothness error           0.005528
# texture error              0.004992
# ...

# %%
import matplotlib.pyplot as plt
feature_scores.plot(kind='barh', color='red')
plt.xlabel("Feature Importance Score")
plt.ylabel("Features")
plt.title("Visualizing Important Features")
plt.show()

# %%
x1 = x.drop(columns=['mean radius', 'mean texture', 'mean perimeter', 'mean area',
       'mean smoothness', 'mean compactness', 'mean concavity','mean symmetry', 'mean fractal dimension',
       'radius error', 'texture error', 'perimeter error', 'area error',
       'smoothness error', 'compactness error', 'concavity error',
       'concave points error', 'symmetry error', 'fractal dimension error', 'worst texture',
       'worst smoothness', 'worst compactness', 'worst concavity', 'worst symmetry', 'worst fractal dimension'], axis=1)
x1
# Out:
#      mean concave points  worst radius  worst perimeter  worst area  \
# 0                0.14710        25.380           184.60      2019.0
# 1                0.07017        24.990           158.80      1956.0
# 2                0.12790        23.570           152.50      1709.0
# 3                0.10520        14.910            98.87       567.7
# 4                0.10430        22.540           152.20      1575.0
# ..                   ...           ...              ...         ...
# 564              0.13890        25.450           166.10      2027.0
# 565              0.09791        23.690           155.00      1731.0
# 566              0.05302        18.980           126.70      1124.0
# 567              0.15200        25.740           184.60      1821.0
# 568              0.00000         9.456            59.16       268.6
#
#      worst concave points
# 0                  0.2654
# 1                  0.1860
# 2                  0.2430
# 3                  0.2575
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x1,y,test_size=0.33,random_state=0)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((381, 5), (188, 5), (381,), (188,))

# %%
rfc=RandomForestClassifier()
rfc.fit(x_train,y_train)
rfc.score(x_test, y_test)*100
# Out:
# 95.2127659574468

# %%
Summary: Using Random Forest Classifier with default parameter we have got accuracy score of 97.20%, and using top features we have got accuracy score of 95.21% which has decreased.
